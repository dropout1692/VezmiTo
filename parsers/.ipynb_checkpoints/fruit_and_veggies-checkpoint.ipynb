# %%
# source: https://www.eufic.org/en/explore-seasonal-fruit-and-vegetables-in-europe

# %%
import sys
# !{sys.executable} -m pip install googletrans==3.1.0a0 beautifulsoup4
# Out:
# Requirement already satisfied: googletrans==3.1.0a0 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (3.1.0a0)
# Requirement already satisfied: beautifulsoup4 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: httpx==0.13.3 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: hstspreload in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.11.1)
# Requirement already satisfied: sniffio in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Requirement already satisfied: chardet==3.* in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: rfc3986<2,>=1.3 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: idna==2.* in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: certifi in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.5.18.1)
# Requirement already satisfied: httpcore==0.9.* in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/davidblanar/miniforge3/lib/python3.9/site-packages (from beautifulsoup4) (2.3.2.post1)

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from googletrans import Translator

# %%
with open("./fruit_and_veggies.html") as f:
    soup = BeautifulSoup(f, 'html.parser')

# %%
obj = {
    "id": [],
    "month": [],
    "type": []
}

elements = soup.find('div', {"id": "Fruit"}).find_all('div', class_="czechrepublic")
for el in elements:
    classnames = el.get('class')
    el_id = el.get('id')
    if "stored" not in el_id:
        months = [item for item in classnames if "czechrepublic" in item and item != "czechrepublic"]
        monthnames = [item.split("-")[0] for item in months]
        obj["id"].append(el_id)
        obj["month"].append(monthnames)
        obj['type'].append(0) # fruit
        
elements = soup.find('div', {"id": "Vegetable"}).find_all('div', class_="czechrepublic")
for el in elements:
    classnames = el.get('class')
    el_id = el.get('id')
    if "stored" not in el_id:
        months = [item for item in classnames if "czechrepublic" in item and item != "czechrepublic"]
        monthnames = [item.split("-")[0] for item in months]
        obj["id"].append(el_id)
        obj["month"].append(monthnames)
        obj['type'].append(1) # vegetable

df = pd.DataFrame(obj).explode("month")

# %%
df.head()
# Out:
#         id      month  type
# 0    apple       july     0
# 0    apple     august     0
# 0    apple  september     0
# 0    apple    october     0
# 1  apricot       july     0

# %%
unique_ids = list(df['id'].unique())
unique_months = list(df['month'].unique())

# %%
translator = Translator()

# %%
def translate(item):
    translated_text = translator.translate(item, dest='sk')
    return translated_text.text

# %%
unique_ids_translated = [translate(item) for item in unique_ids]

# %%
unique_months_translated = [translate(item) for item in unique_months]

# %%
unique_ids_map = {}
for i, item in enumerate(unique_ids):
    unique_ids_map[item] = unique_ids_translated[i]
unique_ids_map
# Out:
# {'apple': 'jablko',
#  'apricot': 'marhuľový',
#  'blackberry': 'ostružina',
#  'blackcurrant': 'čierna ríbezľa',
#  'cherry': 'čerešňa',
#  'grape': 'hrozno',
#  'pear': 'hruška',
#  'plum': 'slivka',
#  'strawberry': 'jahodový',
#  'watermelon': 'vodný melón',
#  'asparagus': 'špargľa',
#  'aubergine': 'baklažán',
#  'beetroot': 'cvikla',
#  'bellpepper': 'bellpepper',
#  'broccoli': 'brokolica',
#  'brusselssprout': 'ružičkový kel',
#  'cabbage': 'kapusta',
#  'carrot': 'mrkva',
#  'cauliflower': 'karfiol',
#  'celery': 'zeler',
#  'chard': 'mangold',
#  'chicory': 'čakanka',
#  'chili': 'čili',
#  'chinesecabbage': 'čínska kapusta',
#  'courgette': 'cuketa',
#  'cress': 'žerucha',
#  'cucumber': 'uhorka',
#  'garlic': 'cesnak',
#  'greenbean': 'zelená fazuľa',
#  'iceberglettuce': 'ľadový šalát',
#  'kohlrabi': 'kaleráb',
#  'lambslettuce': 'jahňacie šaláty',
#  'leek': 'zdalo sa',
#  'lettuce': 'šalát',
#  'onion': 'Cibuľa',
#  'parsleyroot': 'petržlenová vňať',
#  'pea': 'možno',
#  'potato': 'zemiak',
#  'pumpkin': 'tekvica',
#  'radish': 'reďkovka',
#  'redradish': 'prefarbiť',
#  'spinach': 'špenát',
#  'squash': 'squash',
#  'tomato': 'paradajka',
#  'whiteradish': 'biela reďkovka'}

# %%
unique_months_map = {}
for i, item in enumerate(unique_months):
    unique_months_map[item] = unique_months_translated[i]
unique_months_map
# Out:
# {'july': 'júla',
#  'august': 'august',
#  'september': 'september',
#  'october': 'október',
#  'june': 'júna',
#  'may': 'smieť',
#  'november': 'novembra',
#  'december': 'December',
#  'january': 'januára',
#  'february': 'február',
#  'march': 'pochod',
#  'april': 'apríl'}

# %%
def apply_map(item, map_to_apply):
    return map_to_apply[item]

# %%
df2 = df.copy()

# %%
df2['id'] = df['id'].apply(lambda x: apply_map(x, unique_ids_map))

# %%
df2['month'] = df['month'].apply(lambda x: apply_map(x, unique_months_map))

# %%
df2.head()
# Out:
#           id      month  type
# 0     jablko       júla     0
# 0     jablko     august     0
# 0     jablko  september     0
# 0     jablko    október     0
# 1  marhuľový       júla     0

# %%
df2 = df2.replace('marhuľový','marhuľa')
df2 = df2.replace('jahodový','jahoda')
df2 = df2.replace('bellpepper','paprika')
df2 = df2.replace('jahňacie šaláty','jahňací šalát')
df2 = df2.replace('Cibuľa','cibuľa')
df2 = df2.replace('zdalo sa','pór')
df2 = df2.replace('možno','hrach')
df2 = df2.replace('prefarbiť','reďkovka')

df2['id'].unique()
# Out:
# array(['jablko', 'marhuľa', 'ostružina', 'čierna ríbezľa', 'čerešňa',
#        'hrozno', 'hruška', 'slivka', 'jahoda', 'vodný melón', 'špargľa',
#        'baklažán', 'cvikla', 'paprika', 'brokolica', 'ružičkový kel',
#        'kapusta', 'mrkva', 'karfiol', 'zeler', 'mangold', 'čakanka',
#        'čili', 'čínska kapusta', 'cuketa', 'žerucha', 'uhorka', 'cesnak',
#        'zelená fazuľa', 'ľadový šalát', 'kaleráb', 'jahňací šalát', 'pór',
#        'šalát', 'cibuľa', 'petržlenová vňať', 'hrach', 'zemiak',
#        'tekvica', 'reďkovka', 'špenát', 'squash', 'paradajka',
#        'biela reďkovka'], dtype=object)

# %%
df2 = df2.replace('júla','júl')
df2 = df2.replace('júna','jún')
df2 = df2.replace('novembra','november')
df2 = df2.replace('December','december')
df2 = df2.replace('januára','január')
df2 = df2.replace('smieť','máj')
df2 = df2.replace('pochod','marec')
df2 = df2.replace('augusta','august')
df2['month'].unique()
# Out:
# array(['júl', 'august', 'september', 'október', 'jún', 'máj', 'november',
#        'december', 'január', 'február', 'marec', 'apríl'], dtype=object)

# %%
# df['id'].unique()

# %%
# nazov, start, end (cisla mesiacov 1 indexed)
month_index_map = {}
for idx, item in enumerate(['január', 'február', 'marec', 'apríl', 'máj', 'jún', 'júl', 'august', 'september', 'október', 'november', 'december']):
    month_index_map[item] = idx + 1
month_index_map
# Out:
# {'január': 1,
#  'február': 2,
#  'marec': 3,
#  'apríl': 4,
#  'máj': 5,
#  'jún': 6,
#  'júl': 7,
#  'august': 8,
#  'september': 9,
#  'október': 10,
#  'november': 11,
#  'december': 12}

# %%
df2['month_index'] = df2['month'].apply(lambda x: month_index_map[x])
df2.head()
# Out:
#         id      month  type  month_index
# 0   jablko        júl     0            7
# 0   jablko     august     0            8
# 0   jablko  september     0            9
# 0   jablko    október     0           10
# 1  marhuľa        júl     0            7

# %%
aggregated = df2[['id', 'month_index', 'type']].groupby(['id', 'type']).agg({'month_index': ['min', 'max']}).reset_index()
aggregated.columns = ['id', 'type', 'start', 'end']
aggregated['edible'] = 1
aggregated = aggregated[['id', 'start', 'end', 'edible', 'type']]
aggregated
# Out:
#                   id  start  end  edible  type
# 0           baklažán      7   10       1     1
# 1     biela reďkovka      8   10       1     1
# 2          brokolica      6    9       1     1
# 3             cesnak      7    8       1     1
# 4             cibuľa      4    9       1     1
# 5             cuketa      6   10       1     1
# 6             cvikla      6   10       1     1
# 7              hrach      6    8       1     1
# 8             hrozno      8   10       1     0
# 9             hruška      7   10       1     0
# 10            jablko      7   10       1     0
# 11            jahoda      5    9       1     0
# 12     jahňací šalát      4   12       1     1
# 13           kaleráb     10   11       1     1
# 14           kapusta      6   11       1     1
# 15           karfiol      5   10       1     1
# 16           mangold      5   11       1     1
# 17           marhuľa      7    8       1     0
# 18             mrkva      6    9       1     1
# 19         ostružina      8   10       1     0
# 20           paprika      7   10       1     1
# 21         paradajka      5    9       1     1
# 22  petržlenová vňať      9   10       1     1
# 23               pór      6   11       1     1
# 24          reďkovka      4   10       1     1
# 25     ružičkový kel      1   12       1     1
# 26            slivka      7   10       1     0
# 27            squash      7   10       1     1
# 28           tekvica      7   10       1     1
# 29            uhorka      6    8       1     1
# 30       vodný melón      9    9       1     0
# 31     zelená fazuľa      6    9       1     1
# 32             zeler      7   10       1     1
# 33            zemiak      6   10       1     1
# 34           čakanka      9   10       1     1
# 35           čerešňa      6    7       1     0
# 36    čierna ríbezľa      8    8       1     0
# 37              čili      7   10       1     1
# 38    čínska kapusta      8   10       1     1
# 39      ľadový šalát      5   10       1     1
# 40             šalát      5   10       1     1
# 41           špargľa      5    6       1     1
# 42            špenát      5   11       1     1
# 43           žerucha      1   10       1     1

# %%
aggregated.drop_duplicates().to_csv("./fruit_and_veggies.csv")
